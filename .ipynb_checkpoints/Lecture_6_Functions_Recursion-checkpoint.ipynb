# %%
### Function, 

def cal_sum(a, b):
    sum = a+b
    print(sum)
    return sum

cal_sum (2,3)
cal_sum(3,4)
cal_sum(4,5)
# Out:
# 5
# 7
# 9
# 9

# %%
# Function, different type of function, calculated sum 
def cal_sum(a, b): # d(a, b) are parameters 
    return a+b

sum = cal_sum(1,2) #  cal_sum(1,2):Function call, # (1, 2): argumnets
print (sum)
# Out:
# 3

# %%
# 
def cal_avg(a, b, c):
    total = a + b + c
    avg = total / 3
    print(avg)
    
cal_avg(56, 67.5, 56.1)
# Out:
# 59.86666666666667

# %%
##Function Types(Built in Function and User Define Function)
# Wrute a Function to print the lenght of a list  

cities = ["Dhaka", "London", "Cumilla", "Khulna", "Rangpur", "Rajshahi"]
heroes = ["Thor", "SRK", "Allu_Arjun", "RDJ", "Krish"]

def print_len(list):
    print(len(list))

print_len(cities)
print_len(heroes)
# Out:
# 6
# 5

# %%
# Write a Function to print the elements of a list in a single line

cities = ["Dhaka","Rajshahi","Khulna","Rangpur","Comilla",]
heroes  = ["Hulk","Iron_Man","Thor","Spider_Man","Krrish","Jervis"]

print(cities[0],end=" ")
print(heroes[1],end=" ")

def print_len(list):
    print(len(list))

def print_list(list):
    for item in list:
        print (item, end= " ")

print_list(heroes)
# Out:
# Dhaka Iron_Man Hulk Iron_Man Thor Spider_Man Krrish Jervis

# %%
# Write a Function to find the factorial of n (n is the parameter)

def cal_fact(n):
    fact = 1
    for i in range(1, n+1):
        fact *= i 
    print (fact)

cal_fact (5)
# Out:
# 120

# %%
# Write a Function to convert USD to Taka

def converter(usd_val) :
    bdt_value = usd_val * 123
    print(usd_val,"USD =", bdt_val, "BDT")

converter(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 7
#       4     bdt_value = usd_val * 123
#       5     print(usd_value,"USD =", bdt_val, "BDT")
# ----> 7 converter(1)
#
# Cell In[35], line 5, in converter(usd_val)
#       3 def converter(usd_val) :
#       4     bdt_value = usd_val * 123
# ----> 5     print(usd_value,"USD =", bdt_val, "BDT")
#
# NameError: name 'usd_value' is not defined
